# %%
import pandas as pd
import numpy as np

# %%
numbers = [10, 20, 30, 40, 50]

arr = np.array(numbers) # np.array([10, 20, 30, 40, 50])

print(arr)
print(numbers)
# Out:
# [10 20 30 40 50]
# [10, 20, 30, 40, 50]

# %%
print(arr.dtype)
# Out:
# int64

# %%
print(arr.size)
# Out:
# 5

# %%
print(arr.shape)
# Out:
# (5,)

# %%
print(arr.ndim)
# Out:
# 1

# %%
arr2 = np.array([10,20,30], dtype=float)
print(arr2)
print(arr2.dtype)
# Out:
# [10. 20. 30.]
# float64
